# %%
# !pip install selenium
# !pip install webdriver-manager
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: selenium in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (4.36.0)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio<1.0,>=0.30.0 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from selenium) (0.31.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.6.15 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from selenium) (2025.8.3)
# Requirement already satisfied: typing_extensions<5.0,>=4.14.0 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from selenium) (4.14.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.30.0->selenium) (3.10)
# Requirement already satisfied: outcome in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.30.0->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.30.0->selenium) (2.0.0)
# Requirement already satisfied: exceptiongroup in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.30.0->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.30.0->selenium) (2.23)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Requirement already satisfied: webdriver-manager in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (4.0.2)
# Requirement already satisfied: requests in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from webdriver-manager) (2.32.5)
# Requirement already satisfied: python-dotenv in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from webdriver-manager) (1.1.1)
# Requirement already satisfied: packaging in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from webdriver-manager) (24.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khans\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (2025.8.3)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.scrapethissite.com/pages/")

# %%
time.sleep(5)
html_content = driver.page_source
soup = BeautifulSoup(html_content, 'html.parser')

# %%
links = soup.find_all('a')
for link in links:
    print(link.get('href'))
# Out:
# /
# /pages/
# /lessons/
# /faq/
# /login/
# /pages/simple/
# /pages/forms/
# /pages/ajax-javascript/
# /pages/frames/
# /pages/advanced/

# %%
driver.get("https://www.scrapethissite.com/pages/simple/")
time.sleep(5)

# %%
html_content = driver.page_source
soup = BeautifulSoup(html_content, "html.parser")

# %%
countries_data = []

countries = soup.find_all("div", class_="col-md-4 country")  
for country in countries:
    name = country.find("h3", class_="country-name").text.strip()
    capital = country.find("span", class_="country-capital").text.strip()
    population = country.find("span", class_="country-population").text.strip()
    area = country.find("span", class_="country-area").text.strip()
    
    countries_data.append({
        "Name": name,
        "Capital": capital,
        "Population": population,
        "Area": area
    })
driver.quit()

# %%
df = pd.DataFrame(countries_data)
print(df)
# Out:
#                      Name           Capital Population       Area
# 0                 Andorra  Andorra la Vella      84000      468.0
# 1    United Arab Emirates         Abu Dhabi    4975593    82880.0
# 2             Afghanistan             Kabul   29121286   647500.0
# 3     Antigua and Barbuda        St. John's      86754      443.0
# 4                Anguilla        The Valley      13254      102.0
# ..                    ...               ...        ...        ...
# 245                 Yemen             Sanaa   23495361   527970.0
# 246               Mayotte         Mamoudzou     159042      374.0
# 247          South Africa          Pretoria   49000000  1219912.0
# 248                Zambia            Lusaka   13460305   752614.0
# 249              Zimbabwe            Harare   11651858   390580.0
#
# [250 rows x 4 columns]
